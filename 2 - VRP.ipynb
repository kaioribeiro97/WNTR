# %% [markdown]
# # simulação com vrp

# %%
# Create a WaterNetworkModel from an EPANET INP file
import numpy as np
from scipy.stats import lognorm
import networkx as nx
import geopandas as gpd
import matplotlib.pylab as plt
import warnings
import wntr
import folium
from pyproj import Transformer
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.colors as mcolors
import branca.colormap as bcm
from math import sqrt
from wntr.network.elements import Reservoir

# %%
# Funções:
def vrp(wn, trecho):

    pipe = wn.get_link(trecho)
    start_node = pipe.start_node_name
    end_node = pipe.end_node_name
    wn.remove_link(trecho)

    wn.add_valve(
        name='VRP_' + trecho,
        start_node_name=start_node,
        end_node_name=end_node,
        diameter=pipe.diameter,
        valve_type='PRV',           # Tipo de válvula: PRV para redutora de pressão
        minor_loss= 0.0,             # Ajuste conforme necessário
        initial_setting=20.0,       # Pressão de saída desejada em metros (exemplo)
        initial_status='Active'       # Opened, Closed, Active
    )

def resevatorio(wn, nome_reservatorio, node, coord_x,coord_y):    # Nome do reservatório
    base_head = 1156.99              # Carga hidráulica (ajuste conforme sua rede)
    coordinates = (coord_x,coord_y)             # Coordenadas (opcional, ajuste conforme necessário)
    # Parâmetros da tubulação
    nome_tubulacao = 'P_R1_N49'
    comprimento = 0.10                # Comprimento em metros (ajuste conforme necessário)
    diametro = 110                   # Diâmetro em mm (ajuste conforme necessário)
    rugosidade = 140                 # Rugosidade (ajuste conforme necessário)

    # Adiciona o reservatório à rede
    wn.add_reservoir(nome_reservatorio, base_head=base_head, coordinates=coordinates)
    # Adiciona a tubulação conectando o reservatório ao nó N49
    wn.add_pipe(nome_tubulacao, nome_reservatorio, node, length=comprimento, diameter=diametro, roughness=rugosidade)

# %%
# Substitua pelos valores reais das coordenadas (x, y) dos nós
coords = {
    'N17': (182325.334803334, 8236241.429658412),
    'N354': (181617.609217913, 8236027.916901818),
    'N351': (181673.985346249, 8236280.518389829)
}

def distancia(p1, p2):
    return sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2)

comprimento_1 = distancia(coords['N17'], coords['N354'])    # ≈ 15,13 m
comprimento_2 = distancia(coords['N354'], coords['N351'])   # ≈ 22,36 m
fator_escala = 188.12067746 / (comprimento_1 + comprimento_2)
comprimento_1_ajustado = comprimento_1 * fator_escala
comprimento_2_ajustado = comprimento_2 * fator_escala

# %%
# Suppress warning messages that will be addressed in future WNTR releases
warnings.filterwarnings("ignore", message="Column names longer than 10 characters will be truncated when saved to "
            "ESRI Shapefile.")
warnings.filterwarnings("ignore", message="'crs' was not provided.  The output dataset will not have projection information defined and may not be usable in other systems.")
warnings.filterwarnings("ignore", message="Normalized/laundered field name:")
warnings.filterwarnings("ignore", message="Geometry is in a geographic CRS.")
wn = wntr.network.WaterNetworkModel('PK_QD28_TESTE_DOS_NOS_DUPLICADOS (20).inp')
resevatorio(wn, "r1", 'N49',181765.717, 8236835.008)
resevatorio(wn, "r2", 'N46',182189.760, 8234991.779)
# Parâmetros
rugosidade = 140
diametro_mm = 32
diametro_m = diametro_mm / 1000.0

# Remova o trecho antigo
wn.remove_link('P375')

# Adicione os dois novos trechos
wn.add_pipe('P375_1', 'N17', 'N354', length=comprimento_1_ajustado, diameter=diametro_m, roughness=rugosidade)
wn.add_pipe('P375_2', 'N354', 'N351', length=comprimento_2_ajustado, diameter=diametro_m, roughness=rugosidade)

# Adicionar Valvulas
vrp(wn,'P379')
vrp(wn,'P375_1')
vrp(wn,'P366')

sim = wntr.sim.EpanetSimulator(wn)
results = sim.run_sim()

# Extraia pressões do último instante simulado
pressure = results.node['pressure'].iloc[-1]
demanda = results.node['demand'].iloc[-1]
flowrate = results.link['flowrate']
flow_last = flowrate.iloc[-1]
# Substitui valores negativos por zero
pressure = pressure.clip(lower=0)

# Converta as Coordenadas dos Nós para Latitude/Longitude
from pyproj import Transformer

transformer = Transformer.from_crs('EPSG:31983', 'EPSG:4326', always_xy=True)
nodes_latlon = {}
for node in wn.node_name_list:
    x, y = wn.get_node(node).coordinates
    lon, lat = transformer.transform(x, y)
    nodes_latlon[node] = (lat, lon)

# Normaliza as pressões para escala de cores
press_values = list(pressure.values)
# norm = colors.Normalize(vmin=min(press_values), vmax=max(press_values))
# Supondo que press_values já é sua lista de pressões
vmin = min(press_values)
vmax = max(press_values)
# Crie o mapa centralizado em um ponto da rede
lat_centro, lon_centro = list(nodes_latlon.values())[0]
m = folium.Map(location=[lat_centro, lon_centro], zoom_start=15)
velocity = results.link['velocity']


for valve_name in wn.valve_name_list:
    valve = wn.get_link(valve_name)
    start_node = valve.start_node_name
    end_node = valve.end_node_name
    latlon_start = nodes_latlon[start_node]
    latlon_end = nodes_latlon[end_node]
    folium.PolyLine(
        locations=[latlon_start, latlon_end],
        color='black',
        weight=3,
        opacity=0.8,
        popup=f'Válvula {valve_name} ({valve.valve_type})'
    ).add_to(m)

# Adicionar os trechos de redes
for pipe_name in wn.pipe_name_list:
    pipe = wn.get_link(pipe_name)
    start_node = pipe.start_node_name
    end_node = pipe.end_node_name
    latlon_start = nodes_latlon[start_node]
    latlon_end = nodes_latlon[end_node]
    velocity_last = velocity[pipe_name].iloc[-1]*3.6
    flow_value = flow_last[pipe_name]*1000
    popup_text = f"{pipe_name}: Velocidade = {velocity_last:.2f} m/s - Vazão = {flow_value:.2f} l/s"

    folium.PolyLine(
        locations=[latlon_start, latlon_end],
        color='black',
        weight=3,
        opacity=0.7,
        popup=popup_text
    ).add_to(m)


# Adicione cada nó com cor conforme a pressão

vmin = min(press_values)
vmax = max(press_values)
cmap = plt.colormaps['YlOrBr']
colors = [cmap(i / 10) for i in range(11)]
hex_colors = [mcolors.rgb2hex(c) for c in colors]

colormap = bcm.LinearColormap(hex_colors, vmin=vmin, vmax=vmax, caption='Pressão (m)')
colormap.add_to(m)

# Adiciona um ícone no ponto médio de cada VRP
for valve_name in wn.valve_name_list:
    valve = wn.get_link(valve_name)
    start_node = valve.start_node_name
    end_node = valve.end_node_name
    latlon_start = nodes_latlon[start_node]
    latlon_end = nodes_latlon[end_node]
    # Calcula o ponto médio para posicionar o ícone
    lat_valve = (latlon_start[0] + latlon_end[0]) / 2
    lon_valve = (latlon_start[1] + latlon_end[1]) / 2
    folium.Marker(
        location=[lat_valve, lon_valve],
        popup=f'VRP: {valve_name} ({valve.valve_type})',
        icon=folium.CustomIcon('https://raw.githubusercontent.com/kaioribeiro97/WNTR/f0c8942f2398fb38053519aac3e8560e4f609220/imagens/1.svg',
    icon_size=(40, 40),icon_anchor=(20, 40),
)
    ).add_to(m)


for node, (lat, lon) in nodes_latlon.items():
    press = pressure[node]
    deman = demanda[node]
    color = colormap(press)
    node_obj = wn.get_node(node)
    if isinstance(node_obj, Reservoir):
        folium.Marker(
            location=[lat, lon],
            popup=f'Reservatório {node}: {press:.2f} m - Demanda {deman:.5f} l/s',
            icon=folium.CustomIcon('https://raw.githubusercontent.com/kaioribeiro97/WNTR/f0c8942f2398fb38053519aac3e8560e4f609220/imagens/2.svg',
    icon_size=(40, 40),icon_anchor=(20, 40),)
        ).add_to(m)
    else:
        folium.CircleMarker(
            location=[lat, lon],
            radius=8,
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.9,
            popup=f'{node}: {press:.2f} m - Demanda {deman:.5f} l/s'
        ).add_to(m)

m.save('rede_pressao_mapa_VRP.html')


# Gere o mapa interativo e salve em um arquivo HTML
# wntr.graphics.plot_leaflet_network(wn, filename='rede_mapa.html')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 9
#       7 wn = wntr.network.WaterNetworkModel('PK_QD28_TESTE_DOS_NOS_DUPLICADOS (20).inp')
#       8 resevatorio(wn, "r1", 'N49',181765.717, 8236835.008)
# ----> 9 resevatorio(wn, "r2", 'N46')
#      10 # Parâmetros
#      11 rugosidade = 140
#
# TypeError: resevatorio() missing 2 required positional arguments: 'coord_x' and 'coord_y'

# %%
node_obj
# Out:
# <Reservoir 'r1', head=<TimeSeries: base_value=1156.99, pattern_name=None, category='None'>>

# %%
# Listar pressões ordenadas
for node, press in sorted(pressure.items(), key=lambda x: x[1], reverse=True):
    print(f'Nó: {node} | Pressão: {press:.2f} m')
# Out:
# Nó: N18 | Pressão: 66.66 m
# Nó: N19 | Pressão: 66.55 m
# Nó: N20 | Pressão: 64.34 m
# Nó: N17 | Pressão: 62.84 m
# Nó: N21 | Pressão: 62.81 m
# Nó: N22 | Pressão: 60.45 m
# Nó: N16 | Pressão: 60.01 m
# Nó: N15 | Pressão: 57.83 m
# Nó: N326 | Pressão: 56.60 m
# Nó: N191 | Pressão: 54.77 m
# Nó: N192 | Pressão: 54.74 m
# Nó: N187 | Pressão: 54.70 m
# Nó: N188 | Pressão: 54.40 m
# Nó: N64 | Pressão: 54.16 m
# Nó: N189 | Pressão: 54.14 m
# Nó: N14 | Pressão: 54.13 m
# Nó: N186 | Pressão: 54.08 m
# Nó: N65 | Pressão: 53.93 m
# Nó: N23 | Pressão: 53.84 m
# Nó: N190 | Pressão: 53.81 m
# Nó: N193 | Pressão: 53.64 m
# Nó: N185 | Pressão: 53.53 m
# Nó: N207 | Pressão: 52.60 m
# Nó: N194 | Pressão: 52.36 m
# Nó: N363 | Pressão: 51.96 m
# Nó: N370 | Pressão: 51.51 m
# Nó: N195 | Pressão: 51.50 m
# Nó: N203 | Pressão: 51.47 m
# Nó: N325 | Pressão: 51.23 m
# Nó: N202 | Pressão: 51.04 m
# Nó: N206 | Pressão: 50.95 m
# Nó: N24 | Pressão: 50.82 m
# Nó: N176 | Pressão: 50.79 m
# Nó: N196 | Pressão: 50.71 m
# Nó: N177 | Pressão: 50.58 m
# Nó: N175 | Pressão: 50.52 m
# Nó: N174 | Pressão: 50.47 m
# Nó: N178 | Pressão: 50.46 m
# Nó: N364 | Pressão: 50.45 m
# Nó: N327 | Pressão: 50.42 m
# Nó: N63 | Pressão: 50.31 m
# Nó: N180 | Pressão: 50.24 m
# Nó: N179 | Pressão: 50.22 m
# Nó: N173 | Pressão: 50.18 m
# Nó: N200 | Pressão: 50.16 m
# Nó: N201 | Pressão: 50.14 m
# Nó: N369 | Pressão: 50.02 m
# Nó: N172 | Pressão: 49.91 m
# Nó: N181 | Pressão: 49.85 m
# Nó: N197 | Pressão: 49.65 m
# Nó: N171 | Pressão: 49.64 m
# Nó: N182 | Pressão: 49.58 m
# Nó: N170 | Pressão: 49.58 m
# Nó: N169 | Pressão: 49.45 m
# Nó: N183 | Pressão: 49.39 m
# Nó: N168 | Pressão: 49.34 m
# Nó: N204 | Pressão: 49.27 m
# Nó: N199 | Pressão: 49.25 m
# Nó: N198 | Pressão: 49.24 m
# Nó: N205 | Pressão: 49.23 m
# Nó: N324 | Pressão: 49.01 m
# Nó: N184 | Pressão: 48.96 m
# Nó: N365 | Pressão: 48.83 m
# Nó: N371 | Pressão: 48.78 m
# Nó: N212 | Pressão: 48.76 m
# Nó: N66 | Pressão: 48.74 m
# Nó: N213 | Pressão: 48.73 m
# Nó: N211 | Pressão: 48.56 m
# Nó: N215 | Pressão: 48.46 m
# Nó: N208 | Pressão: 48.44 m
# Nó: N214 | Pressão: 48.38 m
# Nó: N368 | Pressão: 48.31 m
# Nó: N216 | Pressão: 48.30 m
# Nó: N167 | Pressão: 48.24 m
# Nó: N209 | Pressão: 48.08 m
# Nó: N217 | Pressão: 48.04 m
# Nó: N160 | Pressão: 48.02 m
# Nó: N210 | Pressão: 48.01 m
# Nó: N378 | Pressão: 47.98 m
# Nó: N62 | Pressão: 47.91 m
# Nó: N230 | Pressão: 47.90 m
# Nó: N218 | Pressão: 47.90 m
# Nó: N166 | Pressão: 47.88 m
# Nó: N229 | Pressão: 47.77 m
# Nó: N228 | Pressão: 47.70 m
# Nó: N219 | Pressão: 47.65 m
# Nó: N161 | Pressão: 47.63 m
# Nó: N227 | Pressão: 47.58 m
# Nó: N13 | Pressão: 47.27 m
# Nó: N220 | Pressão: 47.23 m
# Nó: N226 | Pressão: 47.22 m
# Nó: N372 | Pressão: 47.19 m
# Nó: N225 | Pressão: 47.19 m
# Nó: N366 | Pressão: 47.15 m
# Nó: N224 | Pressão: 47.08 m
# Nó: N223 | Pressão: 46.98 m
# Nó: N165 | Pressão: 46.79 m
# Nó: N222 | Pressão: 46.72 m
# Nó: N221 | Pressão: 46.65 m
# Nó: N162 | Pressão: 46.63 m
# Nó: N367 | Pressão: 46.58 m
# Nó: N25 | Pressão: 46.27 m
# Nó: N377 | Pressão: 46.23 m
# Nó: N164 | Pressão: 46.22 m
# Nó: N234 | Pressão: 45.91 m
# Nó: N233 | Pressão: 45.76 m
# Nó: N163 | Pressão: 45.55 m
# Nó: N231 | Pressão: 45.52 m
# Nó: N379 | Pressão: 45.37 m
# Nó: N373 | Pressão: 45.37 m
# Nó: N236 | Pressão: 45.30 m
# Nó: N237 | Pressão: 45.24 m
# Nó: N232 | Pressão: 45.15 m
# Nó: N67 | Pressão: 45.04 m
# Nó: N235 | Pressão: 44.95 m
# Nó: N159 | Pressão: 44.80 m
# Nó: N376 | Pressão: 44.75 m
# Nó: N386 | Pressão: 44.72 m
# Nó: N238 | Pressão: 44.70 m
# Nó: N158 | Pressão: 44.43 m
# Nó: N241 | Pressão: 44.36 m
# Nó: N153 | Pressão: 44.33 m
# Nó: N242 | Pressão: 44.23 m
# Nó: N380 | Pressão: 44.18 m
# Nó: N61 | Pressão: 44.16 m
# Nó: N26 | Pressão: 44.06 m
# Nó: N243 | Pressão: 44.05 m
# Nó: N240 | Pressão: 43.85 m
# Nó: N157 | Pressão: 43.79 m
# Nó: N244 | Pressão: 43.64 m
# Nó: N154 | Pressão: 43.48 m
# Nó: N245 | Pressão: 43.37 m
# Nó: N156 | Pressão: 43.31 m
# Nó: N385 | Pressão: 43.27 m
# Nó: N239 | Pressão: 43.26 m
# Nó: N155 | Pressão: 42.96 m
# Nó: N374 | Pressão: 42.95 m
# Nó: N68 | Pressão: 42.71 m
# Nó: N27 | Pressão: 42.68 m
# Nó: N246 | Pressão: 42.66 m
# Nó: N12 | Pressão: 42.39 m
# Nó: N335 | Pressão: 42.27 m
# Nó: N384 | Pressão: 42.08 m
# Nó: N381 | Pressão: 41.97 m
# Nó: N341 | Pressão: 41.92 m
# Nó: N342 | Pressão: 41.87 m
# Nó: N336 | Pressão: 41.82 m
# Nó: N28 | Pressão: 41.81 m
# Nó: N387 | Pressão: 41.69 m
# Nó: N394 | Pressão: 41.59 m
# Nó: N249 | Pressão: 41.47 m
# Nó: N337 | Pressão: 41.41 m
# Nó: N340 | Pressão: 41.35 m
# Nó: N375 | Pressão: 41.34 m
# Nó: N382 | Pressão: 41.17 m
# Nó: N251 | Pressão: 41.11 m
# Nó: N250 | Pressão: 41.06 m
# Nó: N388 | Pressão: 41.03 m
# Nó: N29 | Pressão: 41.01 m
# Nó: N393 | Pressão: 40.91 m
# Nó: N338 | Pressão: 40.76 m
# Nó: N252 | Pressão: 40.75 m
# Nó: N339 | Pressão: 40.69 m
# Nó: N383 | Pressão: 40.56 m
# Nó: N30 | Pressão: 40.51 m
# Nó: N248 | Pressão: 40.45 m
# Nó: N60 | Pressão: 40.38 m
# Nó: N258 | Pressão: 40.24 m
# Nó: N253 | Pressão: 40.06 m
# Nó: N259 | Pressão: 40.06 m
# Nó: N247 | Pressão: 39.96 m
# Nó: N31 | Pressão: 39.91 m
# Nó: N389 | Pressão: 39.91 m
# Nó: N323 | Pressão: 39.87 m
# Nó: N392 | Pressão: 39.69 m
# Nó: N32 | Pressão: 39.57 m
# Nó: N69 | Pressão: 39.56 m
# Nó: N257 | Pressão: 39.56 m
# Nó: N33 | Pressão: 39.50 m
# Nó: N254 | Pressão: 39.42 m
# Nó: N395 | Pressão: 39.06 m
# Nó: N402 | Pressão: 38.96 m
# Nó: N265 | Pressão: 38.92 m
# Nó: N59 | Pressão: 38.80 m
# Nó: N266 | Pressão: 38.78 m
# Nó: N152 | Pressão: 38.58 m
# Nó: N260 | Pressão: 38.45 m
# Nó: N256 | Pressão: 38.44 m
# Nó: N34 | Pressão: 38.39 m
# Nó: N390 | Pressão: 38.34 m
# Nó: N396 | Pressão: 38.25 m
# Nó: N329 | Pressão: 38.25 m
# Nó: N391 | Pressão: 38.22 m
# Nó: N401 | Pressão: 38.19 m
# Nó: N36 | Pressão: 38.15 m
# Nó: N145 | Pressão: 38.13 m
# Nó: N35 | Pressão: 38.13 m
# Nó: N151 | Pressão: 38.07 m
# Nó: N37 | Pressão: 37.91 m
# Nó: N255 | Pressão: 37.74 m
# Nó: N146 | Pressão: 37.68 m
# Nó: N150 | Pressão: 37.61 m
# Nó: N397 | Pressão: 37.59 m
# Nó: N147 | Pressão: 37.52 m
# Nó: N261 | Pressão: 37.48 m
# Nó: N149 | Pressão: 37.40 m
# Nó: N264 | Pressão: 37.31 m
# Nó: N267 | Pressão: 37.24 m
# Nó: N273 | Pressão: 37.23 m
# Nó: N400 | Pressão: 37.22 m
# Nó: N148 | Pressão: 37.15 m
# Nó: N274 | Pressão: 37.10 m
# Nó: N70 | Pressão: 37.09 m
# Nó: N330 | Pressão: 36.72 m
# Nó: N410 | Pressão: 36.57 m
# Nó: N411 | Pressão: 36.51 m
# Nó: N403 | Pressão: 36.47 m
# Nó: N398 | Pressão: 36.44 m
# Nó: N399 | Pressão: 36.39 m
# Nó: N328 | Pressão: 36.39 m
# Nó: N418 | Pressão: 36.35 m
# Nó: N263 | Pressão: 36.27 m
# Nó: N58 | Pressão: 36.11 m
# Nó: N427 | Pressão: 36.05 m
# Nó: N268 | Pressão: 36.05 m
# Nó: N11 | Pressão: 35.85 m
# Nó: N331 | Pressão: 35.75 m
# Nó: N419 | Pressão: 35.72 m
# Nó: N434 | Pressão: 35.68 m
# Nó: N412 | Pressão: 35.67 m
# Nó: N272 | Pressão: 35.64 m
# Nó: N144 | Pressão: 35.55 m
# Nó: N417 | Pressão: 35.51 m
# Nó: N137 | Pressão: 35.48 m
# Nó: N426 | Pressão: 35.45 m
# Nó: N38 | Pressão: 35.24 m
# Nó: N262 | Pressão: 35.20 m
# Nó: N143 | Pressão: 35.16 m
# Nó: N275 | Pressão: 35.13 m
# Nó: N332 | Pressão: 35.13 m
# Nó: N269 | Pressão: 35.10 m
# Nó: N404 | Pressão: 34.99 m
# Nó: N409 | Pressão: 34.96 m
# Nó: N138 | Pressão: 34.87 m
# Nó: N281 | Pressão: 34.83 m
# Nó: N142 | Pressão: 34.72 m
# Nó: N405 | Pressão: 34.53 m
# Nó: N71 | Pressão: 34.49 m
# Nó: N408 | Pressão: 34.39 m
# Nó: N282 | Pressão: 34.34 m
# Nó: N139 | Pressão: 34.33 m
# Nó: N413 | Pressão: 34.23 m
# Nó: N416 | Pressão: 34.23 m
# Nó: N271 | Pressão: 34.11 m
# Nó: N141 | Pressão: 33.98 m
# Nó: N406 | Pressão: 33.67 m
# Nó: N276 | Pressão: 33.66 m
# Nó: N420 | Pressão: 33.64 m
# Nó: N140 | Pressão: 33.62 m
# Nó: N428 | Pressão: 33.59 m
# Nó: N333 | Pressão: 33.57 m
# Nó: N425 | Pressão: 33.54 m
# Nó: N407 | Pressão: 33.52 m
# Nó: N433 | Pressão: 33.32 m
# Nó: N136 | Pressão: 33.28 m
# Nó: N280 | Pressão: 33.27 m
# Nó: N442 | Pressão: 33.25 m
# Nó: N57 | Pressão: 33.18 m
# Nó: N270 | Pressão: 33.10 m
# Nó: N277 | Pressão: 32.98 m
# Nó: N435 | Pressão: 32.87 m
# Nó: N283 | Pressão: 32.84 m
# Nó: N135 | Pressão: 32.75 m
# Nó: N129 | Pressão: 32.72 m
# Nó: N414 | Pressão: 32.65 m
# Nó: N415 | Pressão: 32.58 m
# Nó: N421 | Pressão: 32.54 m
# Nó: N10 | Pressão: 32.46 m
# Nó: N424 | Pressão: 32.41 m
# Nó: N429 | Pressão: 32.27 m
# Nó: N289 | Pressão: 32.26 m
# Nó: N134 | Pressão: 32.13 m
# Nó: N130 | Pressão: 32.10 m
# Nó: N72 | Pressão: 32.10 m
# Nó: N290 | Pressão: 31.94 m
# Nó: N432 | Pressão: 31.84 m
# Nó: N131 | Pressão: 31.57 m
# Nó: N133 | Pressão: 31.50 m
# Nó: N39 | Pressão: 31.46 m
# Nó: N422 | Pressão: 31.35 m
# Nó: N430 | Pressão: 31.29 m
# Nó: N441 | Pressão: 31.17 m
# Nó: N284 | Pressão: 31.15 m
# Nó: N288 | Pressão: 31.14 m
# Nó: N423 | Pressão: 31.13 m
# Nó: N431 | Pressão: 31.12 m
# Nó: N279 | Pressão: 31.01 m
# Nó: N436 | Pressão: 30.90 m
# Nó: N56 | Pressão: 30.84 m
# Nó: N132 | Pressão: 30.83 m
# Nó: N278 | Pressão: 30.78 m
# Nó: N125 | Pressão: 30.73 m
# Nó: N297 | Pressão: 30.64 m
# Nó: N291 | Pressão: 30.60 m
# Nó: N126 | Pressão: 30.50 m
# Nó: N334 | Pressão: 30.50 m
# Nó: N128 | Pressão: 30.44 m
# Nó: N124 | Pressão: 30.38 m
# Nó: N127 | Pressão: 30.35 m
# Nó: N285 | Pressão: 30.28 m
# Nó: N298 | Pressão: 30.19 m
# Nó: N108 | Pressão: 30.17 m
# Nó: N9 | Pressão: 30.12 m
# Nó: N440 | Pressão: 30.03 m
# Nó: N123 | Pressão: 29.90 m
# Nó: N287 | Pressão: 29.72 m
# Nó: N111 | Pressão: 29.69 m
# Nó: N110 | Pressão: 29.67 m
# Nó: N122 | Pressão: 29.66 m
# Nó: N112 | Pressão: 29.63 m
# Nó: N121 | Pressão: 29.49 m
# Nó: N73 | Pressão: 29.49 m
# Nó: N292 | Pressão: 29.44 m
# Nó: N437 | Pressão: 29.40 m
# Nó: N322 | Pressão: 29.34 m
# Nó: N109 | Pressão: 29.33 m
# Nó: N113 | Pressão: 29.24 m
# Nó: N120 | Pressão: 29.08 m
# Nó: N439 | Pressão: 29.02 m
# Nó: N296 | Pressão: 28.98 m
# Nó: N286 | Pressão: 28.83 m
# Nó: N119 | Pressão: 28.75 m
# Nó: N299 | Pressão: 28.75 m
# Nó: N450 | Pressão: 28.69 m
# Nó: N293 | Pressão: 28.57 m
# Nó: N55 | Pressão: 28.50 m
# Nó: N438 | Pressão: 28.47 m
# Nó: N443 | Pressão: 28.38 m
# Nó: N118 | Pressão: 28.32 m
# Nó: N107 | Pressão: 28.04 m
# Nó: N40 | Pressão: 28.00 m
# Nó: N117 | Pressão: 27.98 m
# Nó: N115 | Pressão: 27.98 m
# Nó: N114 | Pressão: 27.77 m
# Nó: N116 | Pressão: 27.69 m
# Nó: N92 | Pressão: 27.66 m
# Nó: N74 | Pressão: 27.59 m
# Nó: N106 | Pressão: 27.57 m
# Nó: N93 | Pressão: 27.33 m
# Nó: N449 | Pressão: 27.30 m
# Nó: N8 | Pressão: 27.23 m
# Nó: N103 | Pressão: 27.21 m
# Nó: N295 | Pressão: 27.17 m
# Nó: N102 | Pressão: 27.08 m
# Nó: N300 | Pressão: 27.02 m
# Nó: N444 | Pressão: 27.00 m
# Nó: N96 | Pressão: 26.86 m
# Nó: N94 | Pressão: 26.71 m
# Nó: N97 | Pressão: 26.65 m
# Nó: N54 | Pressão: 26.56 m
# Nó: N105 | Pressão: 26.49 m
# Nó: N294 | Pressão: 26.45 m
# Nó: N448 | Pressão: 26.41 m
# Nó: N445 | Pressão: 26.36 m
# Nó: N321 | Pressão: 26.34 m
# Nó: N101 | Pressão: 26.31 m
# Nó: N104 | Pressão: 26.18 m
# Nó: N301 | Pressão: 26.13 m
# Nó: N98 | Pressão: 26.02 m
# Nó: N95 | Pressão: 26.00 m
# Nó: N304 | Pressão: 25.97 m
# Nó: N100 | Pressão: 25.95 m
# Nó: N320 | Pressão: 25.76 m
# Nó: N91 | Pressão: 25.70 m
# Nó: N99 | Pressão: 25.64 m
# Nó: N458 | Pressão: 25.49 m
# Nó: N451 | Pressão: 25.45 m
# Nó: N84 | Pressão: 25.39 m
# Nó: N41 | Pressão: 25.38 m
# Nó: N75 | Pressão: 25.33 m
# Nó: N313 | Pressão: 25.21 m
# Nó: N90 | Pressão: 25.18 m
# Nó: N319 | Pressão: 25.01 m
# Nó: N85 | Pressão: 24.77 m
# Nó: N447 | Pressão: 24.74 m
# Nó: N317 | Pressão: 24.56 m
# Nó: N53 | Pressão: 24.51 m
# Nó: N318 | Pressão: 24.51 m
# Nó: N457 | Pressão: 24.47 m
# Nó: N452 | Pressão: 24.45 m
# Nó: N89 | Pressão: 24.45 m
# Nó: N314 | Pressão: 24.27 m
# Nó: N315 | Pressão: 24.26 m
# Nó: N88 | Pressão: 24.18 m
# Nó: N446 | Pressão: 24.12 m
# Nó: N316 | Pressão: 24.01 m
# Nó: N86 | Pressão: 23.97 m
# Nó: N465 | Pressão: 23.83 m
# Nó: N87 | Pressão: 23.70 m
# Nó: N83 | Pressão: 23.52 m
# Nó: N459 | Pressão: 23.51 m
# Nó: N42 | Pressão: 23.46 m
# Nó: N76 | Pressão: 23.40 m
# Nó: N453 | Pressão: 23.39 m
# Nó: N456 | Pressão: 23.38 m
# Nó: N353 | Pressão: 23.16 m
# Nó: N82 | Pressão: 23.01 m
# Nó: N454 | Pressão: 22.96 m
# Nó: N455 | Pressão: 22.94 m
# Nó: N77 | Pressão: 22.73 m
# Nó: N352 | Pressão: 22.55 m
# Nó: N460 | Pressão: 22.51 m
# Nó: N464 | Pressão: 22.22 m
# Nó: N81 | Pressão: 22.17 m
# Nó: N78 | Pressão: 22.08 m
# Nó: N43 | Pressão: 21.95 m
# Nó: N461 | Pressão: 21.94 m
# Nó: N80 | Pressão: 21.84 m
# Nó: N463 | Pressão: 21.46 m
# Nó: N79 | Pressão: 21.41 m
# Nó: N350 | Pressão: 21.17 m
# Nó: N462 | Pressão: 21.06 m
# Nó: N466 | Pressão: 20.85 m
# Nó: N473 | Pressão: 20.72 m
# Nó: N44 | Pressão: 20.33 m
# Nó: N343 | Pressão: 20.00 m
# Nó: N354 | Pressão: 20.00 m
# Nó: N355 | Pressão: 20.00 m
# Nó: N472 | Pressão: 19.73 m
# Nó: N467 | Pressão: 19.69 m
# Nó: N474 | Pressão: 19.42 m
# Nó: N46 | Pressão: 19.40 m
# Nó: N303 | Pressão: 19.37 m
# Nó: N351 | Pressão: 19.36 m
# Nó: N312 | Pressão: 19.28 m
# Nó: N311 | Pressão: 19.22 m
# Nó: N302 | Pressão: 19.17 m
# Nó: N362 | Pressão: 19.17 m
# Nó: N481 | Pressão: 19.15 m
# Nó: N469 | Pressão: 19.15 m
# Nó: N470 | Pressão: 19.14 m
# Nó: N471 | Pressão: 19.12 m
# Nó: N468 | Pressão: 19.07 m
# Nó: N305 | Pressão: 19.04 m
# Nó: N45 | Pressão: 18.98 m
# Nó: N306 | Pressão: 18.91 m
# Nó: N310 | Pressão: 18.77 m
# Nó: N308 | Pressão: 18.70 m
# Nó: N309 | Pressão: 18.65 m
# Nó: N51 | Pressão: 18.64 m
# Nó: N307 | Pressão: 18.55 m
# Nó: N50 | Pressão: 18.49 m
# Nó: N344 | Pressão: 18.48 m
# Nó: N349 | Pressão: 18.42 m
# Nó: N356 | Pressão: 18.30 m
# Nó: N52 | Pressão: 18.09 m
# Nó: N361 | Pressão: 17.75 m
# Nó: N348 | Pressão: 17.62 m
# Nó: N480 | Pressão: 17.57 m
# Nó: N475 | Pressão: 17.53 m
# Nó: N49 | Pressão: 17.00 m
# Nó: N476 | Pressão: 16.94 m
# Nó: N345 | Pressão: 16.85 m
# Nó: N479 | Pressão: 16.79 m
# Nó: N477 | Pressão: 16.64 m
# Nó: N478 | Pressão: 16.58 m
# Nó: N347 | Pressão: 16.57 m
# Nó: N357 | Pressão: 16.51 m
# Nó: N482 | Pressão: 16.15 m
# Nó: N360 | Pressão: 16.07 m
# Nó: N346 | Pressão: 16.02 m
# Nó: N491 | Pressão: 15.87 m
# Nó: N483 | Pressão: 14.74 m
# Nó: N358 | Pressão: 14.39 m
# Nó: N490 | Pressão: 14.35 m
# Nó: N486 | Pressão: 14.14 m
# Nó: N492 | Pressão: 14.13 m
# Nó: N484 | Pressão: 14.08 m
# Nó: N485 | Pressão: 14.00 m
# Nó: N487 | Pressão: 13.95 m
# Nó: N359 | Pressão: 13.85 m
# Nó: N488 | Pressão: 13.84 m
# Nó: N489 | Pressão: 13.80 m
# Nó: N501 | Pressão: 12.89 m
# Nó: N493 | Pressão: 11.66 m
# Nó: N494 | Pressão: 11.30 m
# Nó: N500 | Pressão: 11.01 m
# Nó: N495 | Pressão: 10.95 m
# Nó: N496 | Pressão: 10.76 m
# Nó: N499 | Pressão: 10.40 m
# Nó: N498 | Pressão: 9.99 m
# Nó: N497 | Pressão: 9.96 m
# Nó: R1 | Pressão: 0.00 m

# %%
import numpy as np
from scipy.stats import lognorm
import networkx as nx
import geopandas as gpd
import matplotlib.pylab as plt
import warnings
import wntr
import folium
from pyproj import Transformer
# Create a WaterNetworkModel from an EPANET INP file

wn = wntr.network.WaterNetworkModel('Sim_PKW_Q28.inp')
nome_reservatorio = 'R1'         # Nome do reservatório
base_head = 1153.95                # Carga hidráulica (ajuste conforme sua rede)
coordinates = (-47.971286,-15.927268)             # Coordenadas (opcional, ajuste conforme necessário)
# Parâmetros da tubulação
nome_tubulacao = 'P_R1_N35'
comprimento = 0.10                # Comprimento em metros (ajuste conforme necessário)
diametro = 110                   # Diâmetro em mm (ajuste conforme necessário)
rugosidade = 140                 # Rugosidade (ajuste conforme necessário)

# Adiciona o reservatório à rede
wn.add_reservoir(nome_reservatorio, base_head=base_head, coordinates=coordinates)
# Adiciona a tubulação conectando o reservatório ao nó N35
wn.add_pipe(nome_tubulacao, nome_reservatorio, 'N35', length=comprimento, diameter=diametro, roughness=rugosidade)

# %% [markdown]
# ---------------------------------------

# %%
import folium
# Crie o mapa centralizado nas coordenadas do reservatório
m = folium.Map(location=[coordinates[1], coordinates[0]], zoom_start=16)

# Adicione o reservatório com um marcador especial (cor diferente)
folium.Marker(
    location=[coordinates[1], coordinates[0]],
    popup=nome_reservatorio,
    icon=folium.CustomIcon('https://cdn-icons-png.flaticon.com/512/5733/5733770.png',
    icon_size=(20, 20),
)
).add_to(m)

# Adicione os nós restantes da rede (exemplo para todos os nós)
for node_name, node in wn.nodes():
    if node_name != nome_reservatorio:
        if hasattr(node, 'coordinates') and node.coordinates:
            folium.CircleMarker(
                location=[node.coordinates[1], node.coordinates[0]],
                radius=4,
                color='red',
                fill=True,
                fill_color='blue',
                popup=node_name
            ).add_to(m)

# Adicione as tubulações (pipes) como linhas
for pipe_name, pipe in wn.pipes():
    start_node = wn.get_node(pipe.start_node_name)
    end_node = wn.get_node(pipe.end_node_name)
    if hasattr(start_node, 'coordinates') and hasattr(end_node, 'coordinates'):
        folium.PolyLine(
            locations=[
                [start_node.coordinates[1], start_node.coordinates[0]],
                [end_node.coordinates[1], end_node.coordinates[0]]
            ],
            color='gray',
            weight=2,
            popup=pipe_name
        ).add_to(m)

# Salve o mapa em HTML
m.save('rede_mapa_personalizado.html')
